# %% [markdown]
# Alibaba cluster trace v2017
# Workload pods + Cluster nodes

# %% [markdown]
# Leave only add events in cluster trace.

# %%
import pandas as pd
colnames=['timestamp', 'machine_id', 'event_type', 'event_detail', 'number_of_cpus', 'normalized_memory', 'normalized_disk_space'] 
machine_events = pd.read_csv('server_event.csv', names=colnames, header=None)
machine_events = machine_events[machine_events['event_type'] == "add"]
machine_events.to_csv('server_event_add_only.csv', index=False, header=False)
machine_events.describe()
# Out:
#        timestamp   machine_id  number_of_cpus  normalized_memory  \
# count     1313.0  1313.000000          1313.0        1313.000000
# mean         0.0   657.000000            64.0           0.692729
# std          0.0   379.174762             0.0           0.029690
# min          0.0     1.000000            64.0           0.574788
# 25%          0.0   329.000000            64.0           0.689970
# 50%          0.0   657.000000            64.0           0.689970
# 75%          0.0   985.000000            64.0           0.690001
# max          0.0  1313.000000            64.0           1.000000
#
#        normalized_disk_space
# count            1313.000000
# mean                0.999286
# std                 0.024972
# min                 0.095725
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max                 1.000000

# %% [markdown]
# Clear pods which cannot be place on any node.

# %%
colnames=['timestamp', 'machine_id', 'event_type', 'event_detail', 'number_of_cpus', 'normalized_memory', 'normalized_disk_space'] 
machine_events = pd.read_csv('server_event_add_only.csv', names=colnames, header=None)
colnames=['task_create_time', 'task_end_time', 'job_id', 'task_id', 'number_of_instances', 'status', 'number_of_cpus_requested_per_instance_in_the_task', 'normalized_memory_requested_per_instance_in_the_task'] 
batch_tasks = pd.read_csv('batch_task.csv', names=colnames, header=None)
batch_tasks.describe()
# Out:
#        task_create_time  task_end_time        job_id       task_id  \
# count      80553.000000   80553.000000  80553.000000  80553.000000
# mean       34015.217397   34102.648629   6510.637133  40277.000000
# std        17486.557911   17503.364965   3687.839839  23253.792454
# min        -1078.000000    -843.000000      1.000000      1.000000
# 25%        18032.000000   18096.000000   3160.000000  20139.000000
# 50%        40688.000000   40749.000000   6788.000000  40277.000000
# 75%        48749.000000   48853.000000   9241.000000  60415.000000
# max        60181.000000   61668.000000  12951.000000  80553.000000
#
#        number_of_instances  number_of_cpus_requested_per_instance_in_the_task  \
# count         80553.000000                                       71536.000000
# mean            147.844537                                          62.500210
# std             912.187723                                          22.585006
# ...

# %%
batch_tasks = batch_tasks[batch_tasks["number_of_cpus_requested_per_instance_in_the_task"] <= 64]
def filter_out(x):
    for idx_node, row_node in machine_events.iterrows():
        if x["number_of_cpus_requested_per_instance_in_the_task"] <= row_node["number_of_cpus"] and \
            x["normalized_memory_requested_per_instance_in_the_task"] <= row_node["normalized_memory"]:
            return True
    return False

batch_tasks = batch_tasks[batch_tasks.apply(filter_out, axis=1)]
batch_tasks["number_of_cpus_requested_per_instance_in_the_task"] = batch_tasks["number_of_cpus_requested_per_instance_in_the_task"].astype(int)
batch_tasks.to_csv('batch_task_fit_only.csv', index=False, header=False)
batch_tasks.describe()
# Out:
#        task_create_time  task_end_time        job_id       task_id  \
# count      53472.000000   53472.000000  53472.000000  53472.000000
# mean       33978.867968   34171.588813   6527.972771  40369.946701
# std        17210.269129   17160.988692   3609.399784  22767.591623
# min         -849.000000    -843.000000      2.000000      2.000000
# 25%        18968.000000   19726.000000   3787.250000  22596.750000
# 50%        40447.000000   40577.500000   6846.000000  40529.000000
# 75%        48350.000000   48426.000000   9017.000000  59288.250000
# max        59656.000000   61668.000000  12951.000000  80553.000000
#
#        number_of_instances  number_of_cpus_requested_per_instance_in_the_task  \
# count         53472.000000                                       53472.000000
# mean            160.575067                                          49.956239
# std             924.179485                                           0.945956
# ...
